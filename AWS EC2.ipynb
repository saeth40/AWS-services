# %% [markdown]
# # create CE2 instance

# %% [markdown]
# ![image.png](attachment:b169e598-9077-4f8e-9cbf-91aff84fb9a5.png)

# %% [markdown]
# ![image.png](attachment:eb644f51-f5e6-4f7a-95b8-057b2b084543.png)

# %% [markdown]
# # connect to Ubantu EC2 from window cmd

# %%
#  ssh -i "key_name.pem" ubuntu@ec2-3-80-206-52.compute-1.amazonaws.com

# %% [markdown]
# ![image.png](attachment:b8b3ecb9-b85a-4ba8-af59-64c29d890ee5.png)

# %% [markdown]
# # test the EC2 instance

# %%
# sudo apt-get update

# %%
# test installing 
# sudo apt-get install apache2

# %%
# go to the folder var/www/html to locate index.html file
# cd /var/www/html
# see the list of files in the directiry by: ls

# %% [markdown]
# ![image.png](attachment:c736e9fa-cb23-4fbb-9b59-c49aba89c4a7.png)

# %%
# allow http protocal

# %% [markdown]
# ![image.png](attachment:283d4f94-ef3d-4c04-9593-9c2f6a9aace9.png)

# %%
# open the Public IPv4 address to load the index.html

# %% [markdown]
# ![image.png](attachment:1f95819e-7900-4ca9-a5ac-fb74a7172c53.png)
